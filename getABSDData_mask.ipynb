# %%
from getABSDData import getABSDDataFrames
import numpy as np

# %%
t, d, te = getABSDDataFrames()

# %%
t
# Out:
#                          ImageId  \
# 1       data\train\000155de5.jpg
# 15      data\train\00031f145.jpg
# 18      data\train\0005d01c8.jpg
# 19      data\train\0005d01c8.jpg
# 20      data\train\0006c52e8.jpg
# 33      data\train\000e6378b.jpg
# 37      data\train\000fd9827.jpg
# 39      data\train\00113a75c.jpg
# 40      data\train\00113a75c.jpg
# 41      data\train\00113a75c.jpg
# 42      data\train\00113a75c.jpg
# 43      data\train\00113a75c.jpg
# 44      data\train\00113a75c.jpg
# 45      data\train\00113a75c.jpg
# 52      data\train\001566f7c.jpg
# 69      data\train\001e418bc.jpg
# 71      data\train\001eb2794.jpg
# 72      data\train\001eda01f.jpg
# 82      data\train\00269a792.jpg
# 90      data\train\002c78530.jpg
# 91      data\train\002c78530.jpg
# 92      data\train\002d56570.jpg
# 95      data\train\002e85393.jpg
# 98      data\train\002fdcf51.jpg
# 99      data\train\002fdcf51.jpg
# 102     data\train\00319c32d.jpg
# 121     data\train\003d43308.jpg
# ...

# %%
def annotation2area(annotation):
    if isinstance(annotation, float) and math.isnan(annotation):
        return 0
    s = annotation.split()
    return np.asarray(s[1:][::2], dtype=int).sum()

# %%
areas = np.array([annotation2area(ann) for ann in d.EncodedPixels])

# %%
import matplotlib.pyplot  as plt
image = d[areas > 10000].ImageId.iloc[100]

# %%
I = plt.imread(image)
plt.imshow(I)
plt.show(I)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-60-2dc8872f4f24> in <module>()
# ----> 1 I = plt.imread(image)
#       2 plt.imshow(I)
#       3 plt.show(I)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in imread(*args, **kwargs)
#    2231 @docstring.copy_dedent(_imread)
#    2232 def imread(*args, **kwargs):
# -> 2233     return _imread(*args, **kwargs)
#    2234
#    2235
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\image.py in imread(fname, format)
#    1278
#    1279     if ext not in handlers:
# -> 1280         im = pilread(fname)
#    1281         if im is None:
#    1282             raise ValueError('Only know how to handle extensions: %s; '
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\image.py in pilread(fname)
#    1256         except ImportError:
#    1257             return None
# ...
